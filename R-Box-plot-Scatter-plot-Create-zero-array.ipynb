# %%
x1 = c(1,3,6,9,12,4,7,8,11,10) 
y1 = c(1.5,2,7,8,15,5,8,7,11,9)

# %%
x2 = x1*x1/10
x = rbind(x1, x2)
y2 = y1*y1/10
y = rbind(y1, y2)
p1 = rep(1, 10)
p2 = rep(2, 10)
p = rbind(p1, p2)

# %%
plot(x,y, pch=p)
boxplot(t(y))
# Out:
# plot without title
# plot without title
